# %%
import pandas as pd
path = "dataMissingValue.csv"
df = pd.read_csv(path)
df
# Out:
#   Name   School Level Blood Type   Age   Fav Fruit  Shoe Chart
# 0    A    High School         AB  15.0       apple        36.0
# 1    B    High School        NaN  17.0      banana        41.0
# 2    C    High School        NaN   NaN  watermelon         NaN
# 3    D    High School        NaN  16.0         NaN        38.0
# 4    E  Middle School          B  15.0      banana        37.0
# 5    F  Middle School        NaN  14.0      grapes         NaN
# 6    G  Middle School          O   NaN       mango        36.0
# 7    H    High School          A  16.0      papaya        39.0
# 8    I    High School        NaN  18.0         NaN        40.0
# 9    J  Middle School        NaN   NaN     avocado        35.0

# %%
df.isnull().sum()
# Out:
# Name            0
# School Level    0
# Blood Type      6
# Age             3
# Fav Fruit       2
# Shoe Chart      2
# dtype: int64

# %%
percent_missing = 100*df.isnull().mean()
percent_missing
# Out:
# Name             0.0
# School Level     0.0
# Blood Type      60.0
# Age             30.0
# Fav Fruit       20.0
# Shoe Chart      20.0
# dtype: float64

# %%
df.dropna(axis=0)
# Out:
#   Name   School Level Blood Type   Age Fav Fruit  Shoe Chart
# 0    A    High School         AB  15.0     apple        36.0
# 4    E  Middle School          B  15.0    banana        37.0
# 7    H    High School          A  16.0    papaya        39.0

# %%
df.dropna(axis=1)
# Out:
#   Name   School Level
# 0    A    High School
# 1    B    High School
# 2    C    High School
# 3    D    High School
# 4    E  Middle School
# 5    F  Middle School
# 6    G  Middle School
# 7    H    High School
# 8    I    High School
# 9    J  Middle School

# %%
df.dropna(thresh=5)
# Out:
#   Name   School Level Blood Type   Age Fav Fruit  Shoe Chart
# 0    A    High School         AB  15.0     apple        36.0
# 1    B    High School        NaN  17.0    banana        41.0
# 4    E  Middle School          B  15.0    banana        37.0
# 6    G  Middle School          O   NaN     mango        36.0
# 7    H    High School          A  16.0    papaya        39.0

# %%
df.dropna(subset=['Age'])
# Out:
#   Name   School Level Blood Type   Age Fav Fruit  Shoe Chart
# 0    A    High School         AB  15.0     apple        36.0
# 1    B    High School        NaN  17.0    banana        41.0
# 3    D    High School        NaN  16.0       NaN        38.0
# 4    E  Middle School          B  15.0    banana        37.0
# 5    F  Middle School        NaN  14.0    grapes         NaN
# 7    H    High School          A  16.0    papaya        39.0
# 8    I    High School        NaN  18.0       NaN        40.0

# %%
df_drop = df.drop(columns = 'Blood Type')
df_drop
# Out:
#   Name   School Level   Age   Fav Fruit  Shoe Chart
# 0    A    High School  15.0       apple        36.0
# 1    B    High School  17.0      banana        41.0
# 2    C    High School   NaN  watermelon         NaN
# 3    D    High School  16.0         NaN        38.0
# 4    E  Middle School  15.0      banana        37.0
# 5    F  Middle School  14.0      grapes         NaN
# 6    G  Middle School   NaN       mango        36.0
# 7    H    High School  16.0      papaya        39.0
# 8    I    High School  18.0         NaN        40.0
# 9    J  Middle School   NaN     avocado        35.0

# %%
df_filled = df_drop.copy ()
df_filled['Age'] = df_filled['Age'].fillna(df_filled['Age'].mean())
df_filled
# Out:
#   Name   School Level        Age   Fav Fruit  Shoe Chart
# 0    A    High School  15.000000       apple        36.0
# 1    B    High School  17.000000      banana        41.0
# 2    C    High School  15.857143  watermelon         NaN
# 3    D    High School  16.000000         NaN        38.0
# 4    E  Middle School  15.000000      banana        37.0
# 5    F  Middle School  14.000000      grapes         NaN
# 6    G  Middle School  15.857143       mango        36.0
# 7    H    High School  16.000000      papaya        39.0
# 8    I    High School  18.000000         NaN        40.0
# 9    J  Middle School  15.857143     avocado        35.0

# %%
df_filled['Shoe Chart'] = df['Shoe Chart'].fillna(df['Shoe Chart'].median())
df_filled
# Out:
#   Name   School Level        Age   Fav Fruit  Shoe Chart
# 0    A    High School  15.000000       apple        36.0
# 1    B    High School  17.000000      banana        41.0
# 2    C    High School  15.857143  watermelon        37.5
# 3    D    High School  16.000000         NaN        38.0
# 4    E  Middle School  15.000000      banana        37.0
# 5    F  Middle School  14.000000      grapes        37.5
# 6    G  Middle School  15.857143       mango        36.0
# 7    H    High School  16.000000      papaya        39.0
# 8    I    High School  18.000000         NaN        40.0
# 9    J  Middle School  15.857143     avocado        35.0

# %%
df_filled['Fav Fruit'] = df['Fav Fruit'].fillna(df['Fav Fruit'].mode().iloc[0])
df_filled
# Out:
#   Name   School Level        Age   Fav Fruit  Shoe Chart
# 0    A    High School  15.000000       apple        36.0
# 1    B    High School  17.000000      banana        41.0
# 2    C    High School  15.857143  watermelon        37.5
# 3    D    High School  16.000000      banana        38.0
# 4    E  Middle School  15.000000      banana        37.0
# 5    F  Middle School  14.000000      grapes        37.5
# 6    G  Middle School  15.857143       mango        36.0
# 7    H    High School  16.000000      papaya        39.0
# 8    I    High School  18.000000      banana        40.0
# 9    J  Middle School  15.857143     avocado        35.0

# %%
df_filled2 = df_drop.copy()
df_filled2['Shoe Chart'] = df_filled2['Shoe Chart'].replace("", None).bfill()
df_filled2
# Out:
#   Name   School Level   Age   Fav Fruit  Shoe Chart
# 0    A    High School  15.0       apple        36.0
# 1    B    High School  17.0      banana        41.0
# 2    C    High School   NaN  watermelon        38.0
# 3    D    High School  16.0         NaN        38.0
# 4    E  Middle School  15.0      banana        37.0
# 5    F  Middle School  14.0      grapes        36.0
# 6    G  Middle School   NaN       mango        36.0
# 7    H    High School  16.0      papaya        39.0
# 8    I    High School  18.0         NaN        40.0
# 9    J  Middle School   NaN     avocado        35.0

# %%
df_filled2['Fav Fruit'] = df_filled2['Fav Fruit'].replace("", None).ffill()
df_filled2
# Out:
#   Name   School Level   Age   Fav Fruit  Shoe Chart
# 0    A    High School  15.0       apple        36.0
# 1    B    High School  17.0      banana        41.0
# 2    C    High School   NaN  watermelon        38.0
# 3    D    High School  16.0  watermelon        38.0
# 4    E  Middle School  15.0      banana        37.0
# 5    F  Middle School  14.0      grapes        36.0
# 6    G  Middle School   NaN       mango        36.0
# 7    H    High School  16.0      papaya        39.0
# 8    I    High School  18.0      papaya        40.0
# 9    J  Middle School   NaN     avocado        35.0

# %%
path = "weight-height_outlier.csv"
df2 = pd.read_csv(path)
df2
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
import seaborn as sns
sns.boxplot(df2['Height'])
# Out:
# <Axes: ylabel='Height'>

# %%
import numpy as np
# Identifikasi Q1 Q3
q1, q3 = np.percentile(df2['Height'], [25, 75])
# Hitung IQR
iqr = q3 - q1
# Cari lower dan upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Hapus outliers
clean_data = df2[(df2['Height'] >= lower_bound)
 & (df2['Height'] <= upper_bound)]
sns.boxplot(clean_data['Height'])
# Out:
# <Axes: ylabel='Height'>

# %%
sns.boxplot(df2['Weight'])
# Out:
# <Axes: ylabel='Weight'>

# %%
# Identifikasi Q1 Q3
q1, q3 = np.percentile(df2['Weight'], [25, 75])
# Hitung IQR
iqr = q3 - q1
# Cari lower dan upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Hapus outliers
clean_data = df2[(df2['Weight'] >= lower_bound)
 & (df2['Weight'] <= upper_bound)]
sns.boxplot(clean_data['Weight'])
# Out:
# <Axes: ylabel='Weight'>

# %%
import matplotlib.pyplot as plt

# Kolom yang ingin dianalisis
columns_to_plot = ['Weight', 'Height']

# Memastikan kolom tersedia
columns_to_plot = [col for col in columns_to_plot if col in df2.columns]

fig, axs = plt.subplots(
    len(columns_to_plot),
    1,
    dpi=95,
    figsize=(7, 5 * len(columns_to_plot))
)

if len(columns_to_plot) == 1:
    axs = [axs]

for i, col in enumerate(columns_to_plot):
    axs[i].boxplot(df2[col], vert=False)
    axs[i].set_ylabel(col)
    axs[i].set_xlabel('Value')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\personal\AppData\Local\Temp\ipykernel_21652\1765503279.py:20: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   axs[i].boxplot(df2[col], vert=False)
# C:\Users\personal\AppData\Local\Temp\ipykernel_21652\1765503279.py:20: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   axs[i].boxplot(df2[col], vert=False)

# %%
def remove_outliers_sequentially(df2, columns):
    df_cleaned = df2.copy()

    for col in columns:
        q1, q3 = np.percentile(df_cleaned[col].dropna(), [25, 75])
        iqr = q3 - q1
        lower_bound = q1 - (1.5 * iqr)
        upper_bound = q3 + (1.5 * iqr)

        df_cleaned = df_cleaned[
            df_cleaned[col].between(lower_bound, upper_bound)
        ]

    return df_cleaned


clean_data = remove_outliers_sequentially(df2, ['Height', 'Weight'])

columns_to_plot = ['Weight', 'Height']

fig, axs = plt.subplots(
    len(columns_to_plot),
    1,
    dpi=95,
    figsize=(7, 5 * len(columns_to_plot))
)

axs = np.atleast_1d(axs)

for i, col in enumerate(columns_to_plot):
    axs[i].boxplot(clean_data[col], vert=False)
    axs[i].set_ylabel(col)
    axs[i].set_xlabel('Value')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\personal\AppData\Local\Temp\ipykernel_21652\2193688837.py:31: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   axs[i].boxplot(clean_data[col], vert=False)
# C:\Users\personal\AppData\Local\Temp\ipykernel_21652\2193688837.py:31: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   axs[i].boxplot(clean_data[col], vert=False)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
# Memisahkan kolom numerik dan non-numerik
numeric_cols = clean_data.select_dtypes(include=[np.number]).columns # Ambil kolom
non_numeric_cols = clean_data.select_dtypes(exclude=[np.number]).columns # Ambil k
rescaled_numeric = scaler.fit_transform(clean_data[numeric_cols])
rescaled_numeric[:]
# Out:
# array([[0.83480376, 0.92524773],
#        [0.6086688 , 0.49939825],
#        [0.84654949, 0.76925146],
#        ...,
#        [0.38928431, 0.31834619],
#        [0.61993463, 0.50764944],
#        [0.30339752, 0.23901104]], shape=(9992, 2))

# %%
#Konversi kembali hasil scaling ke DataFrame
rescaled_df = pd.DataFrame(rescaled_numeric, columns=numeric_cols, index=clean_data.index)

#Gabungkan kembali dengan kolom non-numerik tanpa mengubah jumlah baris
final_df = pd.concat([clean_data[non_numeric_cols], rescaled_df], axis=1)

final_df
# Out:
#       Gender    Height    Weight
# 0       Male  0.834804  0.925248
# 1       Male  0.608669  0.499398
# 2       Male  0.846549  0.769251
# 3       Male  0.740332  0.808322
# 4       Male  0.657774  0.735053
# ...      ...       ...       ...
# 9995  Female  0.492177  0.362771
# 9996  Female  0.532113  0.545189
# 9997  Female  0.389284  0.318346
# 9998  Female  0.619935  0.507649
# 9999  Female  0.303398  0.239011
#
# [9992 rows x 3 columns]

# %% [markdown]
# ## 2. Menampilkan df.isnull().sum()
# ### Ketika Semua missing value sudah diatasi

# %% [markdown]
# ### 2.1 membaca Dataset

# %%
path = "Titanic-Dataset.csv" 
df = pd.read_csv(path)

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 2.2 Mengecek Jumlah Missing Value
# #### Untuk mengetahui jumlah data yang hilang pada setiap kolom digunakan

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### 2.3 Menghitung Persentase Missing Value
#
# #### Persentase missing value dihitung untuk mengetahui seberapa banyak data yang hilang pada setiap kolom.

# %%
percent_missing = 100 * df.isnull().mean() 

percent_missing
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %% [markdown]
# ### 2.4 Menangani Missing Value pada Kolom Age
#
# #### Kolom Age merupakan data numerik. Missing value pada kolom ini diisi menggunakan nilai rata-rata atau mean.

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %% [markdown]
# ### 2.5 Menangani Missing Value pada Kolom Embarked
#
# #### Kolom Embarked merupakan data kategorikal. Missing value diisi menggunakan nilai yang paling sering muncul atau mode.

# %%
df['Embarked'] = df['Embarked'].fillna(
     df['Embarked'].mode().iloc[0] 
)

# %% [markdown]
# ### 2.6 Menghapus Kolom Cabin
#
# #### Kolom Cabin memiliki jumlah missing value yang sangat banyak. Oleh karena itu, kolom tersebut dihapus.

# %%
df = df.drop(columns='Cabin')

# %% [markdown]
# ### 2.7 Mengecek Missing Value Setelah Ditangani
#
# #### Setelah seluruh proses handling missing value selesai, dilakukan pengecekan kembali.

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# #### Berdasarkan hasil tersebut, seluruh missing value pada dataset telah berhasil ditangani.

# %% [markdown]
# ## 3. Handling Outliers
#
# ### Dataset yang digunakan adalah diabetes.csv.

# %% [markdown]
# ### 3.1 Membaca Dataset

# %%
path = "diabetes.csv" 
df2 = pd.read_csv(path) 

df2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ### 3.2 Melihat Ukuran Dataset

# %%
df2.shape
# Out:
# (768, 9)

# %% [markdown]
# ## 4. Memilih Kolom untuk Deteksi Outlier
#
# #### - Glucose
# #### - BloodPressure
# #### - BMI

# %% [markdown]
# ### 5. Deteksi Outlier pada Glucose
#
# #### 5.1 Visualisasi Boxplot

# %%
sns.boxplot(df2['Glucose']) 
plt.title("Boxplot Glucose") 
plt.show()

# %% [markdown]
# ### 5.2 Menghitung IQR

# %%
q1, q3 = np.percentile(df2['Glucose'], [25, 75])

iqr = q3 - q1

lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)

print("Q1:", q1)
print("Q3:", q3)
print("IQR:", iqr)
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
# Out:
# Q1: 99.0
# Q3: 140.25
# IQR: 41.25
# Lower Bound: 37.125
# Upper Bound: 202.125

# %% [markdown]
# ### 5.3 Menghapus Outlier Glucose

# %%
clean_glucose = df2[
    (df2['Glucose'] >= lower_bound) &
    (df2['Glucose'] <= upper_bound)
]

print("Jumlah data sebelum:", len(df2))
print("Jumlah data sesudah:", len(clean_glucose))
# Out:
# Jumlah data sebelum: 768
# Jumlah data sesudah: 763

# %% [markdown]
# ### 6. Deteksi Outlier pada BloodPressure
# ### 6.1 Visualisasi Boxplot

# %%
sns.boxplot(df2['BloodPressure']) 
plt.title("Boxplot BloodPressure") 
plt.show()

# %% [markdown]
# ### 6.2 Menghitung IQR

# %%
q1, q3 = np.percentile(df2['BloodPressure'], [25, 75])

iqr = q3 - q1

lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)

print("Q1:", q1)
print("Q3:", q3)
print("IQR:", iqr)
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
# Out:
# Q1: 62.0
# Q3: 80.0
# IQR: 18.0
# Lower Bound: 35.0
# Upper Bound: 107.0

# %% [markdown]
# ### 6.3 Menghapus Outlier BloodPressure

# %%
clean_bloodpressure = df2[
    (df2['BloodPressure'] >= lower_bound) &
    (df2['BloodPressure'] <= upper_bound)
]

print("Jumlah data sebelum:", len(df2))
print("Jumlah data sesudah:", len(clean_bloodpressure))
# Out:
# Jumlah data sebelum: 768
# Jumlah data sesudah: 723

# %% [markdown]
# ### 7. Deteksi Outlier pada BMI
# ### 7.1 Visualisasi Boxplot

# %%
sns.boxplot(df2['BMI'])
plt.title("Boxplot BMI")
plt.show()

# %% [markdown]
# ### 7.2 Menghitung IQR

# %%
q1, q3 = np.percentile(df2['BMI'], [25,75])

iqr = q3 - q1

lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)

print("Q1:", q1)
print("Q3:", q3)
print("IQR:", iqr)
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
# Out:
# Q1: 27.3
# Q3: 36.6
# IQR: 9.3
# Lower Bound: 13.35
# Upper Bound: 50.550000000000004

# %% [markdown]
# ### 7.3 Menghapus Outlier BMI

# %%
clean_bmi = df2[
    (df2['BMI'] >= lower_bound) &
    (df2['BMI'] <= upper_bound)
]

print("Jumlah data sebelum:", len(df2))
print("Jumlah data sesudah:", len(clean_bmi))
# Out:
# Jumlah data sebelum: 768
# Jumlah data sesudah: 749

# %% [markdown]
# ### 8. Handling Outlier Secara Berurutan
#
# #### Untuk melakukan handling outlier pada ketiga kolom sekaligus, digunakan metode IQR secara berurutan.

# %%
def remove_outliers_sequentially(df, columns):
    df_cleaned = df.copy()

    for col in columns:
        q1, q3 = np.percentile(
            df_cleaned[col].dropna(),
            [25, 75]
        )

        iqr = q3 - q1

        lower_bound = q1 - (1.5 * iqr)
        upper_bound = q3 + (1.5 * iqr)

        df_cleaned = df_cleaned[
            (df_cleaned[col] >= lower_bound) &
            (df_cleaned[col] <= upper_bound)
        ]

    return df_cleaned

# %%
clean_data = remove_outliers_sequentially( df2, ['Glucose', 'BloodPressure', 'BMI'] )

# %% [markdown]
# ### 8.1 Membandingkan Jumlah Data

# %%
print("Jumlah data sebelum:", len(df2)) 
print("Jumlah data sesudah:", len(clean_data)) 
print("Jumlah data yang dihapus:", len(df2) - len(clean_data))
# Out:
# Jumlah data sebelum: 768
# Jumlah data sesudah: 709
# Jumlah data yang dihapus: 59

# %% [markdown]
# ### 9. Visualisasi Setelah Handling Outlier

# %%
columns_to_plot = [
    'Glucose',
    'BloodPressure',
    'BMI'
]

for col in columns_to_plot:
    plt.figure(figsize=(7, 4))
    plt.boxplot(clean_data[col], vert=False)
    plt.xlabel(col)
    plt.title("Boxplot " + col + " Setelah Handling Outlier")
    plt.show()
# Out:
# C:\Users\personal\AppData\Local\Temp\ipykernel_21652\3769789801.py:9: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   plt.boxplot(clean_data[col], vert=False)
# C:\Users\personal\AppData\Local\Temp\ipykernel_21652\3769789801.py:9: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   plt.boxplot(clean_data[col], vert=False)
# C:\Users\personal\AppData\Local\Temp\ipykernel_21652\3769789801.py:9: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   plt.boxplot(clean_data[col], vert=False)

# %% [markdown]
# ### 10. Kesimpulan
# Pada dataset Titanic-Dataset.csv, missing value ditemukan pada beberapa kolom. Kolom Age ditangani menggunakan mean, kolom Embarked menggunakan mode, sedangkan kolom Cabin dihapus karena memiliki jumlah missing value yang sangat banyak. Setelah proses tersebut, hasil df.isnull().sum() menunjukkan bahwa seluruh missing value telah berhasil ditangani.
#
# Pada dataset diabetes.csv, dilakukan deteksi outlier pada tiga kolom yaitu Glucose, BloodPressure, dan BMI. Deteksi dilakukan menggunakan boxplot dan metode Interquartile Range (IQR). Setelah proses handling outlier secara berurutan, jumlah data berkurang dari 768 menjadi 709 data.
